# %% [markdown]
# <a href="https://colab.research.google.com/github/debashisdotchatterjee/aim_dspp_2026/blob/main/aim_dspp_simulation_colab_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run /content/aim_dspp_simulation_colab.py
# Out:
# AIM-DSPP SIMULATION STUDY
# ========================================================================================
# Device: cpu
# Quick mode: False
# Output directory: /content/AIM_DSPP_Simulation_Outputs
# No benchmark selection is conditional on its performance.
#
#
# [1/7] Simulating the main AIM-DSPP dataset ...
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/01_path_anatomy.png
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/01_structural_diagnostics.csv
#
# ========================================================================================
# TABLE 1 — Structural diagnostics
# ========================================================================================
#                     Diagnostic    Empirical  Theory/Target
# 0        Pearson residual mean    -0.002649       0.000000
# 1    Pearson residual variance     0.989147       1.000000
# 2  Time-rescaling KS statistic     0.003353       0.000000
# 3    Time-rescaling KS p-value     0.947777            NaN
# 4          Empirical mean N(T)   268.688889     269.068340
# 5      Empirical variance N(T)  4143.048190    4176.443050
# 6      Fano factor Var[N]/E[N]    15.419500      15.521867
# 7     Var(Lambda) contribution  3907.374709    3907.374709
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/02_structural_diagnostics.png
# [2/7] Demonstrating multiplicative non-identifiability ...
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/02_identifiability.csv
#
# ========================================================================================
# TABLE 2 — Multiplicative non-identifiability check
# ========================================================================================
#                          Quantity         Value
# 0            max |lambda-lambda'|  7.105427e-15
# 1    max relative intensity error  2.492466e-16
# 2     conditional loglik original -4.000313e+02
# 3  conditional loglik transformed -4.000313e+02
# 4      absolute loglik difference  0.000000e+00
# 5                     mean log(A) -2.960595e-17
# 6                    mean log(A') -2.368476e-17
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/03_identifiability.png
# [3/7] Fitting conditional-likelihood models ...
# Paths: train=50, validation=15, test=25
# [Linear AIM  ] epoch=   1 train=0.761979 val=0.777279 lr=0.025
# [Linear AIM  ] epoch= 100 train=0.703624 val=0.724086 lr=0.0138
# [Linear AIM  ] early stop at epoch 193; best val=0.723929
# [Neural AIM  ] epoch=   1 train=0.774333 val=0.753358 lr=0.008
# [Neural AIM  ] epoch= 100 train=0.664503 val=0.684816 lr=0.008
# [Neural AIM  ] epoch= 200 train=0.660454 val=0.680919 lr=0.008
# [Neural AIM  ] epoch= 300 train=0.660230 val=0.680745 lr=0.0044
# [Neural AIM  ] epoch= 400 train=0.660196 val=0.680756 lr=0.00133
# [Neural AIM  ] early stop at epoch 442; best val=0.680739
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/03_model_comparison.csv
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/03b_pathwise_model_performance.csv
#
# ========================================================================================
# TABLE 3 — Held-out model comparison
# ========================================================================================
#              Model   NLL/bin  Poisson deviance/bin  Intensity RMSE  \
# 0         Cox-only  0.873890              1.047439       16.168424
# 1       Linear AIM  0.807010              0.913680        9.792266
# 2  Neural AIM-DSPP  0.766193              0.832046        1.395398
# 3           Oracle  0.765287              0.830233        0.000000
#
#    Log-intensity RMSE  Intensity MAE  Rescaling KS D  Rescaling KS p
# 0            0.706068      11.554983        0.166117   1.459983e-160
# 1            0.478143       6.789511        0.066209    9.617761e-26
# 2            0.065190       0.893013        0.008104    7.727287e-01
# 3            0.000000       0.000000        0.007292    8.693718e-01
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/04_calibration_deciles.csv
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/04_estimation_and_calibration.png
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/05_training_and_pathwise_performance.png
# [4/7] Running stability/coupling experiment ...
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/05_stability.csv
#
# ========================================================================================
# TABLE 4 — Law-level stability experiment
# ========================================================================================
#    delta    mean_D  empirical_coupling_mismatch  exact_E_1_minus_exp_minus_D  \
# 0  0.000  0.000000                     0.000000                     0.000000
# 1  0.025  0.232018                     0.180769                     0.204981
# 2  0.050  0.461611                     0.365385                     0.363290
# 3  0.100  0.913368                     0.576923                     0.583230
# 4  0.200  1.786311                     0.815385                     0.808154
# 5  0.350  3.017026                     0.926923                     0.930478
# 6  0.550  4.509909                     0.984615                     0.977657
# 7  0.800  6.147042                     1.000000                     0.992940
#
#    mean_Lipschitz_bound_raw  mean_Lipschitz_bound_clipped
# 0                  0.000000                      0.000000
# 1                  0.280740                      0.280740
# 2                  0.561479                      0.561479
# 3                  1.122959                      1.000000
# 4                  2.245917                      1.000000
# 5                  3.930355                      1.000000
# 6                  6.176272                      1.000000
# 7                  8.983668                      1.000000
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/06_stability_theorem.png
# [5/7] Running neural universal-approximation experiment ...
# Training universal-approximation network width=2 ...
# Training universal-approximation network width=4 ...
# Training universal-approximation network width=8 ...
# Training universal-approximation network width=16 ...
# Training universal-approximation network width=32 ...
# Training universal-approximation network width=64 ...
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/06_universal_approximation.csv
#
# ========================================================================================
# TABLE 5 — Universal approximation and law-level diagnostics
# ========================================================================================
#    width  score_sup_error_eps  score_RMSE  mean_abs_modulation_error  \
# 0      2             1.762022    0.357653                   0.070046
# 1      4             0.856209    0.108654                   0.018130
# 2      8             0.376122    0.033602                   0.004819
# 3     16             0.382420    0.019681                   0.003081
# 4     32             0.467654    0.022698                   0.004201
# 5     64             0.419187    0.018542                   0.002933
#
#    mean_coupling_disagreement_bound  theorem_TV_upper_bound_raw  \
# 0                          0.102293                    0.812152
# 1                          0.027935                    0.394644
# 2                          0.007430                    0.173362
# 3                          0.004902                    0.176265
# 4                          0.006475                    0.215551
# 5                          0.004427                    0.193212
#
#    theorem_TV_upper_bound_clipped  mean_R_exposure
# 0                        0.812152         1.536402
# 1                        0.394644         1.536402
# 2                        0.173362         1.536402
# 3                        0.176265         1.536402
# 4                        0.215551         1.536402
# 5                        0.193212         1.536402
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/07_universal_approximation.png
# [6/7] Running long-horizon LLN/CLT experiment ...
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/07_long_run.csv
# Saved table:  AIM_DSPP_Simulation_Outputs/tables/07b_clt_diagnostic.csv
#
# ========================================================================================
# TABLE 6A — Compensator LLN diagnostics
# ========================================================================================
#    horizon  mean_N_over_Lambda  median_N_over_Lambda       q05       q95  \
# 0      5.0            0.987505              0.973916  0.722083  1.284429
# 1     10.0            1.007865              1.003102  0.778640  1.228806
# 2     20.0            0.999026              1.002032  0.859581  1.151145
# 3     40.0            1.001283              0.996973  0.893928  1.112640
# 4     70.0            1.002960              1.001833  0.929611  1.076171
# 5    100.0            1.006126              1.004482  0.941720  1.069285
#
#    RMSE_from_1
# 0     0.180658
# 1     0.129951
# 2     0.093816
# 3     0.065319
# 4     0.045648
# 5     0.038999
# ========================================================================================
# TABLE 6B — Random-compensator CLT diagnostic
# ========================================================================================
#        mean        sd     KS_D      KS_p
# 0  0.154211  0.975618  0.08448  0.034629
# Saved figure: AIM_DSPP_Simulation_Outputs/figures/08_long_run_theory.png
# [7/7] Writing LaTeX-ready section and packaging outputs ...
# Saved LaTeX section: AIM_DSPP_Simulation_Outputs/simulation_section_auto.tex
#
# ========================================================================================
# SIMULATION COMPLETE
# ========================================================================================
# Elapsed: 1.26 minutes
# Output folder: /content/AIM_DSPP_Simulation_Outputs
# ZIP archive:   /content/AIM_DSPP_Simulation_Outputs.zip
# All tables were printed inline and all figures were displayed inline.
# Triggering Colab download of the ZIP ...

# %% [markdown]
# Real Data

# %% [markdown]
# I selected two real biological repeated-count datasets that fit the AIM-DSPP framework particularly well.
#
# **Dataset 1 — `MASS::epil`** contains 236 two-week seizure-count observations from 59 epilepsy patients. An eight-week pre-treatment seizure count is available before randomization, so the code uses:
#
# $$R_i = \frac{\text{baseline seizures}_i}{4}$$
#
# as the patient's externally observed two-week directing intensity. The original data analysis is Thall & Vail (1990), DOI 10.2307/2532086.
#
# **Dataset 2 — `glmmTMB::Owls`** contains 599 repeated observations of sibling-negotiation/begging counts from barn-owl nestlings, together with nest, food treatment, provisioning-parent sex, arrival time, and brood size. The biological source is Roulin & Bersier (2007), DOI 10.1016/j.anbehav.2007.01.027.
#
# Both are loaded first through `statsmodels.datasets.get_rdataset`, which is the official `statsmodels` mechanism for accessing datasets from R packages; a direct Rdatasets CSV route is included only as a fallback.
#
# ### Instructions
#
# Download the complete Colab code `AIM_DSPP_RealBiology_Colab.py` or download the code and instructions together in `AIM_DSPP_RealBiology_Download.zip`.
#
# In Colab, upload the `.py` file and run:
#
# ```python
# %run /content/AIM_DSPP_RealBiology_Colab.py

# %%
# %run /content/AIM_DSPP_RealBiology_Colab_CORRECTED.py
# Out:
# Installing missing package: pyreadr
# ================================================================================================
# AIM-DSPP REAL BIOLOGICAL DATA STUDY
# ================================================================================================
# Device: cpu
# Output directory: /content/AIM_DSPP_RealBiology_Outputs
# Benchmark set is fixed a priori; test performance does not determine model inclusion.
# Exact event times are unavailable; randomized PIT is used instead of time-rescaling.
# Downloading official glmmTMB::Owls from:
#   https://raw.githubusercontent.com/glmmTMB/glmmTMB/master/glmmTMB/data/Owls.rda
# Owls loaded successfully: 599 rows x 8 columns.
#
# Dataset loading routes:
#   Epilepsy: statsmodels.datasets.get_rdataset('epil', package='MASS')
#   Owls:     https://raw.githubusercontent.com/glmmTMB/glmmTMB/master/glmmTMB/data/Owls.rda
#
# ------------------------------------------------------------------------------------------------
# Table 0. Biological datasets and AIM-DSPP empirical interpretation
# ------------------------------------------------------------------------------------------------
#          Dataset                       Biological response  Rows  \
# 0     MASS::epil          Two-week epileptic seizure count   236
# 1  glmmTMB::Owls  Sibling-negotiation / begging-call count   599
#
#    Biological units     Unit                        Directing baseline R  \
# 0                59  patient              pre-treatment 8-week count / 4
# 1                27     nest  history-only shrunk nest rate x brood size
#
#           Exposure                                       Python route  \
# 0  2 weeks per row  statsmodels.datasets.get_rdataset('epil', pack...
# 1       brood size  https://raw.githubusercontent.com/glmmTMB/glmm...
#
#               Primary source DOI
# 0                10.2307/2532086
# 1  10.1016/j.anbehav.2007.01.027
# ------------------------------------------------------------------------------------------------
# Table 1. Epilepsy split and count summary
# ------------------------------------------------------------------------------------------------
#         split  rows  subjects  mean_count  variance_count  mean_baseline_R  \
# 0        test    48        12    5.000000       20.468085         6.812500
# 1       train   152        38    9.585526      185.383365         8.578947
# 2  validation    36         9    7.027778      174.084921         5.861111
#
#    variance_mean_ratio
# 0             4.093617
# 1            19.339926
# 2            24.770977
# ------------------------------------------------------------------------------------------------
# Table 2. Epilepsy dispersion by treatment and period
# ------------------------------------------------------------------------------------------------
#          trt  period   n      mean    variance     zeros    mean_R  \
# 0    placebo       1  28  9.357143  102.756614  0.035714  7.696429
# 1    placebo       2  28  8.285714   66.656085  0.107143  7.696429
# 2    placebo       3  28  8.785714  215.285714  0.107143  7.696429
# 3    placebo       4  28  7.964286   58.183862  0.035714  7.696429
# 4  progabide       1  31  8.580645  332.718280  0.096774  7.903226
# 5  progabide       2  31  8.419355  140.651613  0.032258  7.903226
# 6  progabide       3  31  8.129032  193.049462  0.161290  7.903226
# 7  progabide       4  31  6.709677  126.879570  0.193548  7.903226
#
#    variance_mean_ratio
# 0            10.981623
# 1             8.044700
# 2            24.504065
# 3             7.305597
# 4            38.775439
# 5            16.705747
# 6            23.748148
# 7            18.909936
# ------------------------------------------------------------------------------------------------
# Table 3. Owl history/train/validation/test split summary
# ------------------------------------------------------------------------------------------------
#         split  rows  nests  mean_count  variance_count    mean_R  mean_brood  \
# 0     history   209     27    6.306220       38.117317  6.308645    4.401914
# 1        test   120     27    7.058333       52.593207  6.271792    4.391667
# 2       train   178     27    7.157303       48.720879  6.354944    4.393258
# 3  validation    92     27    6.369565       40.719064  6.291621    4.369565
#
#    variance_mean_ratio
# 0             6.044400
# 1             7.451222
# 2             6.807156
# 3             6.392754
# ------------------------------------------------------------------------------------------------
# Table 4. Owl count dispersion by food treatment and parent sex
# ------------------------------------------------------------------------------------------------
#   FoodTreatment SexParent    n      mean   variance     zeros  mean_brood  \
# 0      Deprived    Female  123  7.260163  40.030121  0.203252    4.016260
# 1      Deprived      Male  197  8.725888  42.057132  0.101523    4.517766
# 2      Satiated    Female  122  4.754098  42.699363  0.442623    4.540984
# 3      Satiated      Male  157  5.305732  42.970031  0.363057    4.414013
#
#    variance_mean_ratio
# 0             5.513667
# 1             4.819811
# 2             8.981590
# 3             8.098793
# ------------------------------------------------------------------------------------------------
# Table 5. History-only nest frailty estimates
# ------------------------------------------------------------------------------------------------
#                Nest  hist_calls  hist_exposure  hist_n  raw_history_rate  \
# 0             Jeuss         6.0             35       7          0.171429
# 1           Henniez         0.0             10       5          0.000000
# 2          Etrabloz        46.0             60      12          0.766667
# 3            Lucens        35.0             40      10          0.875000
# 4             Seiry        50.0             54       9          0.925926
# 5             Forel         0.0              4       1          0.000000
# 6              GDLV        19.0             20       4          0.950000
# 7            Bochet        37.0             32       8          1.156250
# 8        AutavauxTV        62.0             50      10          1.240000
# 9           Payerne        56.0             45       9          1.244444
# 10          StAubin        42.0             32       8          1.312500
# 11           Montet        98.0             70      14          1.400000
# 12          Marnand        52.0             36       9          1.444444
# 13         Yvonnand       133.0             84      12          1.583333
# 14            Lully        39.0             24       6          1.625000
# 15            Sevaz         3.0              1       1          3.000000
# 16       Gletterens        18.0             10       5          1.800000
# 17           Rueyes        41.0             24       6          1.708333
# 18             Trey        60.0             35       7          1.714286
# 19      LesPlanches        32.0             18       6          1.777778
# 20           Franex        62.0             36       9          1.722222
# 21  CorcellesFavres        23.0             12       4          1.916667
# 22      Champmartin        55.0             30      10          1.833333
# 23         Chevroux        17.0              8       4          2.125000
# 24           Murist        62.0             32       8          1.937500
# 25           Oleyes       185.0             90      18          2.055556
# 26          ChEsard        85.0             28       7          3.035714
#
#     shrunk_nest_rate
# 0           0.451691
# 1           0.716304
# 2           0.861801
# 3           0.986522
# 4           1.005095
# 5           1.023292
# 6           1.110870
# 7           1.222050
# 8           1.272101
# 9           1.278656
# 10          1.341097
# 11          1.404076
# 12          1.441871
# 13          1.567299
# 14          1.568414
# 15          1.575099
# 16          1.616304
# 17          1.627238
# 18          1.651691
# 19          1.654503
# 20          1.659263
# 21          1.696640
# 22          1.733152
# 23          1.740338
# 24          1.817288
# 25          1.993261
# 26          2.613844
# ================================================================================================
# FITTING FIXED MODEL SET: Epilepsy
# ================================================================================================
#   -> Linear Poisson AIM
#   <- Linear done; -> Spline Poisson AIM
#   <- Spline done; -> Poisson Gradient Boosting
#   <- HGB done; -> Neural AIM-DSPP
#   <- Neural done
#
# ================================================================================================
# FITTING FIXED MODEL SET: Owls
# ================================================================================================
#   -> Linear Poisson AIM
#   <- Linear done; -> Spline Poisson AIM
#   <- Spline done; -> Poisson Gradient Boosting
#   <- HGB done; -> Neural AIM-DSPP
#   <- Neural done
#
# ------------------------------------------------------------------------------------------------
# Epilepsy tuning diagnostic: linear
# ------------------------------------------------------------------------------------------------
#      alpha  ValidationNLL
# 0  0.00001       5.158812
# 1  0.00010       5.158439
# 2  0.00100       5.154742
# 3  0.01000       5.120554
# 4  0.10000       4.916466
# 5  1.00000       4.560132
# ------------------------------------------------------------------------------------------------
# Epilepsy tuning diagnostic: spline
# ------------------------------------------------------------------------------------------------
#     knots   alpha  ValidationNLL
# 0       3  0.0001       4.945011
# 1       3  0.0010       5.019155
# 2       3  0.0100       5.184755
# 3       3  0.1000       4.971161
# 4       4  0.0001       4.185133
# 5       4  0.0010       4.560354
# 6       4  0.0100       5.207737
# 7       4  0.1000       5.183271
# 8       5  0.0001       3.953100
# 9       5  0.0010       4.371662
# 10      5  0.0100       5.104760
# 11      5  0.1000       5.243980
# ------------------------------------------------------------------------------------------------
# Epilepsy tuning diagnostic: histgb
# ------------------------------------------------------------------------------------------------
#    max_depth  learning_rate   l2  ValidationNLL
# 0          2           0.03  0.0       4.649385
# 1          2           0.06  1.0       4.869865
# 2          3           0.03  0.5       4.868514
# 3          3           0.06  1.0       4.600393
# 4          4           0.03  1.0       4.805601
# 5          4           0.05  2.0       4.753787
# ------------------------------------------------------------------------------------------------
# Epilepsy tuning diagnostic: neural_restarts
# ------------------------------------------------------------------------------------------------
#    Restart      Seed  BestEpoch  BestValidationNLL  EpochsRun
# 0        1  20261824          5           4.539267        165
# 1        2  20261855          6           4.491054        166
# 2        3  20261886          6           4.619097        166
# ------------------------------------------------------------------------------------------------
# Epilepsy tuning diagnostic: neural_history
# ------------------------------------------------------------------------------------------------
#      epoch  TrainObjective  ValidationNLL  LearningRate
# 0        1      -15.477033       4.725362       0.00800
# 1        2      -15.625721       4.645959       0.00800
# 2        3      -15.752469       4.580007       0.00800
# 3        4      -15.862049       4.529630       0.00800
# 4        5      -15.953752       4.498366       0.00800
# ..     ...             ...            ...           ...
# 161    162      -16.975018       7.724913       0.00242
# 162    163      -16.977678       7.761554       0.00242
# 163    164      -16.980314       7.798469       0.00242
# 164    165      -16.982920       7.835432       0.00242
# 165    166      -16.985498       7.872235       0.00242
#
# [166 rows x 4 columns]
# ------------------------------------------------------------------------------------------------
# Owl tuning diagnostic: linear
# ------------------------------------------------------------------------------------------------
#      alpha  ValidationNLL
# 0  0.00001       4.225932
# 1  0.00010       4.225390
# 2  0.00100       4.221449
# 3  0.01000       4.213351
# 4  0.10000       4.210881
# 5  1.00000       4.247080
# ------------------------------------------------------------------------------------------------
# Owl tuning diagnostic: spline
# ------------------------------------------------------------------------------------------------
#     knots   alpha  ValidationNLL
# 0       3  0.0001       4.324878
# 1       3  0.0010       4.303310
# 2       3  0.0100       4.260342
# 3       3  0.1000       4.228669
# 4       4  0.0001       4.207834
# 5       4  0.0010       4.235669
# 6       4  0.0100       4.257424
# 7       4  0.1000       4.225714
# 8       5  0.0001       4.327731
# 9       5  0.0010       4.313459
# 10      5  0.0100       4.261387
# 11      5  0.1000       4.170865
# ------------------------------------------------------------------------------------------------
# Owl tuning diagnostic: histgb
# ------------------------------------------------------------------------------------------------
#    max_depth  learning_rate   l2  ValidationNLL
# 0          2           0.03  0.0       4.470339
# 1          2           0.06  1.0       4.820909
# 2          3           0.03  0.5       4.606000
# 3          3           0.06  1.0       4.943189
# 4          4           0.03  1.0       4.867197
# 5          4           0.05  2.0       5.105966
# ------------------------------------------------------------------------------------------------
# Owl tuning diagnostic: neural_restarts
# ------------------------------------------------------------------------------------------------
#    Restart      Seed  BestEpoch  BestValidationNLL  EpochsRun
# 0        1  20262324         18           4.188219        178
# 1        2  20262355         21           4.208033        181
# 2        3  20262386          7           4.162733        167
# ------------------------------------------------------------------------------------------------
# Owl tuning diagnostic: neural_history
# ------------------------------------------------------------------------------------------------
#      epoch  TrainObjective  ValidationNLL  LearningRate
# 0        1       -6.954499       4.558785       0.00800
# 1        2       -7.104488       4.415569       0.00800
# 2        3       -7.203048       4.316357       0.00800
# 3        4       -7.267100       4.248826       0.00800
# 4        5       -7.309298       4.204109       0.00800
# ..     ...             ...            ...           ...
# 162    163       -7.679855       4.825926       0.00242
# 163    164       -7.681845       4.827651       0.00242
# 164    165       -7.683830       4.829567       0.00242
# 165    166       -7.685811       4.831588       0.00242
# 166    167       -7.687787       4.833656       0.00242
#
# [167 rows x 4 columns]
# ------------------------------------------------------------------------------------------------
# Test performance: Epilepsy
# ------------------------------------------------------------------------------------------------
#                        Model       NLL  PoissonDeviance      RMSE       MAE  \
# 0    Directing baseline only  2.723519         2.390240  4.386889  3.052083
# 1            Neural AIM-DSPP  2.838061         2.619324  4.787875  3.222433
# 2         Linear Poisson AIM  2.898309         2.739820  4.967169  3.341517
# 3         Spline Poisson AIM  3.029002         3.001206  4.483267  3.551511
# 4  Poisson Gradient Boosting  3.754153         4.451509  5.196815  3.727736
#
#    MeanObserved  MeanPredicted  PredObsRatio  PearsonDispersion    PIT_KS  \
# 0           5.0       6.812500      1.362500           1.877236  0.295089
# 1           5.0       7.253913      1.450783           1.955257  0.323475
# 2           5.0       7.330023      1.466005           2.052095  0.293318
# 3           5.0       7.003237      1.400647           2.308603  0.354244
# 4           5.0       6.051442      1.210288           4.929672  0.239571
#
#       PIT_p  PIT_mean   PIT_var
# 0  0.000336  0.340472  0.092957
# 1  0.000057  0.328026  0.087176
# 2  0.000374  0.331573  0.091054
# 3  0.000007  0.304920  0.104235
# 4  0.006571  0.455953  0.141932
# ------------------------------------------------------------------------------------------------
# Calibration table: Epilepsy
# ------------------------------------------------------------------------------------------------
#                         Model  CalibrationBin   n  mean_observed  \
# 0     Directing baseline only               1   8       2.125000
# 1     Directing baseline only               2   4       3.000000
# 2     Directing baseline only               3  16       3.125000
# 3     Directing baseline only               4   4       3.250000
# 4     Directing baseline only               5   4       7.500000
# 5     Directing baseline only               6   8      11.750000
# 6     Directing baseline only               7   4       6.000000
# 7          Linear Poisson AIM               1   6       1.666667
# 8          Linear Poisson AIM               2   6       3.166667
# 9          Linear Poisson AIM               3   6       3.666667
# 10         Linear Poisson AIM               4   6       3.333333
# 11         Linear Poisson AIM               5   6       2.666667
# 12         Linear Poisson AIM               6   6       5.833333
# 13         Linear Poisson AIM               7   6      11.500000
# 14         Linear Poisson AIM               8   6       8.166667
# 15         Spline Poisson AIM               1   6       2.500000
# 16         Spline Poisson AIM               2   6       3.000000
# 17         Spline Poisson AIM               3   6       3.333333
# 18         Spline Poisson AIM               4   6       4.166667
# 19         Spline Poisson AIM               5   6       3.000000
# 20         Spline Poisson AIM               6   6       4.833333
# 21         Spline Poisson AIM               7   6      11.000000
# 22         Spline Poisson AIM               8   6       8.166667
# 23  Poisson Gradient Boosting               1   6       3.666667
# 24  Poisson Gradient Boosting               2   6       6.000000
# 25  Poisson Gradient Boosting               3   6       2.333333
# 26  Poisson Gradient Boosting               4   6       2.500000
# 27  Poisson Gradient Boosting               5   6       7.500000
# 28  Poisson Gradient Boosting               6   6       4.666667
# 29  Poisson Gradient Boosting               7   6       3.333333
# 30  Poisson Gradient Boosting               8   6      10.000000
# 31            Neural AIM-DSPP               1   6       1.333333
# 32            Neural AIM-DSPP               2   6       3.333333
# 33            Neural AIM-DSPP               3   6       4.000000
# 34            Neural AIM-DSPP               4   6       2.833333
# 35            Neural AIM-DSPP               5   6       2.666667
# 36            Neural AIM-DSPP               6   6       6.166667
# 37            Neural AIM-DSPP               7   6      11.500000
# 38            Neural AIM-DSPP               8   6       8.166667
#
#     mean_predicted  sum_observed  sum_predicted  ObservedPredictedRatio
# 0         2.125000          17.0      17.000000                1.000000
# 1         3.250000          12.0      13.000000                0.923077
# 2         4.437500          50.0      71.000000                0.704225
# 3         5.500000          13.0      22.000000                0.590909
# 4         8.250000          30.0      33.000000                0.909091
# 5        13.000000          94.0     104.000000                0.903846
# 6        16.750000          24.0      67.000000                0.358209
# 7         1.972548          10.0      11.835289                0.844931
# 8         3.356317          19.0      20.137900                0.943495
# 9         4.208320          22.0      25.249919                0.871290
# 10        4.468407          20.0      26.810445                0.745978
# 11        5.109346          16.0      30.656073                0.521919
# 12        7.714476          35.0      46.286857                0.756154
# 13       13.223386          69.0      79.340318                0.869671
# 14       18.587385          49.0     111.524308                0.439366
# 15        3.146211          15.0      18.877266                0.794607
# 16        3.781403          18.0      22.688416                0.793356
# 17        4.753972          20.0      28.523833                0.701168
# 18        5.912789          25.0      35.476737                0.704687
# 19        6.674205          18.0      40.045233                0.449492
# 20        7.565054          29.0      45.390322                0.638903
# 21       10.085173          66.0      60.511040                1.090710
# 22       14.107084          49.0      84.642505                0.578905
# 23        1.307912          22.0       7.847472                2.803451
# 24        2.040182          36.0      12.241093                2.940914
# 25        3.200118          14.0      19.200709                0.729140
# 26        4.283808          15.0      25.702845                0.583593
# 27        5.591555          45.0      33.549331                1.341308
# 28        6.752322          28.0      40.513931                0.691120
# 29        9.050937          20.0      54.305620                0.368286
# 30       16.184703          60.0      97.108217                0.617867
# 31        1.795214           8.0      10.771282                0.742716
# 32        3.380003          20.0      20.280016                0.986193
# 33        4.204390          24.0      25.226342                0.951386
# 34        4.601176          17.0      27.607058                0.615785
# 35        5.271422          16.0      31.628532                0.505872
# 36        7.548608          37.0      45.291649                0.816928
# 37       13.166116          69.0      78.996694                0.873454
# 38       18.064374          49.0     108.386241                0.452087
# ------------------------------------------------------------------------------------------------
# Held-out biological-unit aggregate counts: Epilepsy
# ------------------------------------------------------------------------------------------------
#    subject  Observed  Directing baseline only  Linear Poisson AIM  \
# 0       12        30                     33.0           33.506526
# 1       13        16                     18.0           17.208610
# 2       17         6                     18.0           17.893767
# 3       19        15                     18.0           18.461483
# 4       23        13                     17.0           17.351186
# 5       32        13                     10.0           10.293660
# 6       38        24                     67.0           75.153800
# 7       40         4                      7.0            6.893426
# 8       42        12                     13.0           14.786103
# 9       45        39                     38.0           45.581887
# 10       5        55                     66.0           70.128939
# 11      50        13                     22.0           24.581722
#
#     Spline Poisson AIM  Poisson Gradient Boosting  Neural AIM-DSPP
# 0            25.501347                   8.793853        32.556016
# 1            12.563548                   5.735878        16.706551
# 2            24.389279                  35.975496        17.970635
# 3            26.466737                  22.155291        19.528858
# 4            24.829020                  15.111953        18.375608
# 5            17.158949                  16.806414         9.602170
# 6            57.183236                  29.316513        72.188501
# 7            15.330892                  14.445181         6.347989
# 8            14.260048                   5.558834        16.152000
# 9            36.467552                  24.156315        46.514080
# 10           50.579349                  72.782586        68.680355
# 11           31.425395                  39.630904        23.565052
# ------------------------------------------------------------------------------------------------
# Cluster-bootstrap uncertainty: Epilepsy
# ------------------------------------------------------------------------------------------------
#                         Model           Metric  BootstrapMean     CI2.5  \
# 0     Directing baseline only              NLL       2.716222  2.089110
# 1     Directing baseline only  PoissonDeviance       2.402105  1.270378
# 2     Directing baseline only             RMSE       4.244321  2.299509
# 3     Directing baseline only              MAE       3.031444  1.767969
# 4          Linear Poisson AIM              NLL       2.890450  2.130140
# 5          Linear Poisson AIM  PoissonDeviance       2.750561  1.381593
# 6          Linear Poisson AIM             RMSE       4.776732  2.358226
# 7          Linear Poisson AIM              MAE       3.317135  1.861786
# 8          Spline Poisson AIM              NLL       3.025054  2.551655
# 9          Spline Poisson AIM  PoissonDeviance       3.019769  1.986542
# 10         Spline Poisson AIM             RMSE       4.414573  3.235354
# 11         Spline Poisson AIM              MAE       3.530638  2.552325
# 12  Poisson Gradient Boosting              NLL       3.749422  2.884184
# 13  Poisson Gradient Boosting  PoissonDeviance       4.468506  2.748143
# 14  Poisson Gradient Boosting             RMSE       5.107646  3.622832
# 15  Poisson Gradient Boosting              MAE       3.712396  2.544019
# 16            Neural AIM-DSPP              NLL       2.829358  2.112214
# 17            Neural AIM-DSPP  PoissonDeviance       2.628377  1.320800
# 18            Neural AIM-DSPP             RMSE       4.605574  2.322303
# 19            Neural AIM-DSPP              MAE       3.194725  1.828445
#
#       CI97.5
# 0   3.596951
# 1   4.068715
# 2   6.278238
# 3   4.794531
# 4   3.994984
# 5   4.858837
# 6   7.302622
# 7   5.366912
# 8   3.629377
# 9   4.390770
# 10  5.742967
# 11  4.758276
# 12  4.635631
# 13  6.306360
# 14  6.514280
# 15  5.020616
# 16  3.866352
# 17  4.600979
# 18  7.000819
# 19  5.173058
# ------------------------------------------------------------------------------------------------
# Paired cluster-bootstrap NLL differences versus Neural AIM-DSPP: Epilepsy
# ------------------------------------------------------------------------------------------------
#                    Benchmark                  Comparison  MeanDifference  \
# 0    Directing baseline only  Benchmark NLL - Neural NLL       -0.113136
# 1         Linear Poisson AIM  Benchmark NLL - Neural NLL        0.061092
# 2         Spline Poisson AIM  Benchmark NLL - Neural NLL        0.195696
# 3  Poisson Gradient Boosting  Benchmark NLL - Neural NLL        0.920064
#
#       CI2.5    CI97.5  BootstrapFractionNeuralBetter
# 0 -0.298002  0.027323                       0.073333
# 1 -0.022053  0.159752                       0.910667
# 2 -0.387748  0.636354                       0.786667
# 3 -0.373650  2.074616                       0.917333
# ------------------------------------------------------------------------------------------------
# Test performance: Owls
# ------------------------------------------------------------------------------------------------
#                        Model       NLL  PoissonDeviance      RMSE       MAE  \
# 0         Spline Poisson AIM  4.779443         6.748608  6.471534  5.133484
# 1         Linear Poisson AIM  4.890566         6.970854  6.572898  5.298310
# 2            Neural AIM-DSPP  4.951759         7.093238  6.614594  5.242477
# 3  Poisson Gradient Boosting  5.166418         7.522557  6.876539  5.229103
# 4    Directing baseline only  5.537747         8.265214  7.271628  5.830120
#
#    MeanObserved  MeanPredicted  PredObsRatio  PearsonDispersion    PIT_KS  \
# 0      7.058333       6.871807      0.973574           7.715989  0.343026
# 1      7.058333       6.973022      0.987913           8.222510  0.333308
# 2      7.058333       6.496445      0.920394           8.715081  0.332273
# 3      7.058333       7.108476      1.007104          10.633057  0.315453
# 4      7.058333       6.271792      0.888566          10.249372  0.320222
#
#           PIT_p  PIT_mean   PIT_var
# 0  4.124171e-13  0.423520  0.175102
# 1  2.189966e-12  0.412715  0.176603
# 2  2.608281e-12  0.439232  0.179511
# 3  4.100155e-11  0.423151  0.162849
# 4  1.907561e-11  0.444909  0.189301
# ------------------------------------------------------------------------------------------------
# Calibration table: Owls
# ------------------------------------------------------------------------------------------------
#                         Model  CalibrationBin   n  mean_observed  \
# 0     Directing baseline only               1  19       6.947368
# 1     Directing baseline only               2  13       6.769231
# 2     Directing baseline only               3  16       3.375000
# 3     Directing baseline only               4  12       6.500000
# 4     Directing baseline only               5  17       6.529412
# 5     Directing baseline only               6  13       8.615385
# 6     Directing baseline only               7  19       8.315789
# 7     Directing baseline only               8  11      10.363636
# 8          Linear Poisson AIM               1  15       6.466667
# 9          Linear Poisson AIM               2  15       1.733333
# 10         Linear Poisson AIM               3  15       5.000000
# 11         Linear Poisson AIM               4  15       3.666667
# 12         Linear Poisson AIM               5  15       8.400000
# 13         Linear Poisson AIM               6  15       9.333333
# 14         Linear Poisson AIM               7  15       8.600000
# 15         Linear Poisson AIM               8  15      13.266667
# 16         Spline Poisson AIM               1  15       3.200000
# 17         Spline Poisson AIM               2  15       4.400000
# 18         Spline Poisson AIM               3  15       5.133333
# 19         Spline Poisson AIM               4  15       7.666667
# 20         Spline Poisson AIM               5  15       7.733333
# 21         Spline Poisson AIM               6  15       7.466667
# 22         Spline Poisson AIM               7  15       6.066667
# 23         Spline Poisson AIM               8  15      14.800000
# 24  Poisson Gradient Boosting               1  15       3.133333
# 25  Poisson Gradient Boosting               2  15       3.200000
# 26  Poisson Gradient Boosting               3  15       7.400000
# 27  Poisson Gradient Boosting               4  15       9.800000
# 28  Poisson Gradient Boosting               5  15       6.266667
# 29  Poisson Gradient Boosting               6  15       4.866667
# 30  Poisson Gradient Boosting               7  15       9.466667
# 31  Poisson Gradient Boosting               8  15      12.333333
# 32            Neural AIM-DSPP               1  15       5.400000
# 33            Neural AIM-DSPP               2  15       4.466667
# 34            Neural AIM-DSPP               3  15       4.400000
# 35            Neural AIM-DSPP               4  15       3.866667
# 36            Neural AIM-DSPP               5  15       9.600000
# 37            Neural AIM-DSPP               6  15       7.466667
# 38            Neural AIM-DSPP               7  15       7.600000
# 39            Neural AIM-DSPP               8  15      13.666667
#
#     mean_predicted  sum_observed  sum_predicted  ObservedPredictedRatio
# 0         2.907497         132.0      55.242442                2.389467
# 1         4.515170          88.0      58.697205                1.499220
# 2         5.193066          54.0      83.089055                0.649905
# 3         5.841582          78.0      70.098978                1.112712
# 4         6.381016         111.0     108.477273                1.023256
# 5         6.872946         112.0      89.348299                1.253521
# 6         8.896980         158.0     169.042616                0.934676
# 7        10.783559         114.0     118.619151                0.961059
# 8         2.596371          97.0      38.945569                2.490656
# 9         4.157790          26.0      62.366844                0.416888
# 10        5.282490          75.0      79.237344                0.946523
# 11        5.943230          55.0      89.148454                0.616948
# 12        6.904833         126.0     103.572496                1.216539
# 13        8.160485         140.0     122.407277                1.143723
# 14        9.658502         129.0     144.877529                0.890407
# 15       13.080474         199.0     196.207113                1.014234
# 16        2.801304          48.0      42.019559                1.142325
# 17        4.126831          66.0      61.902462                1.066193
# 18        5.130344          77.0      76.955160                1.000583
# 19        5.974694         115.0      89.620406                1.283190
# 20        6.905904         116.0     103.588562                1.119815
# 21        7.916906         112.0     118.753591                0.943129
# 22        8.805416          91.0     132.081237                0.688970
# 23       13.313056         222.0     199.695834                1.111691
# 24        2.234801          47.0      33.522008                1.402064
# 25        3.642449          48.0      54.636733                0.878530
# 26        4.455015         111.0      66.825222                1.661049
# 27        5.484682         147.0      82.270237                1.786794
# 28        6.687084          94.0     100.306267                0.937130
# 29        8.356528          73.0     125.347913                0.582379
# 30       10.509971         142.0     157.649562                0.900732
# 31       15.497277         185.0     232.459162                0.795839
# 32        2.450974          81.0      36.764608                2.203206
# 33        3.893531          67.0      58.402958                1.147202
# 34        5.065269          66.0      75.979038                0.868661
# 35        5.800706          58.0      87.010592                0.666586
# 36        6.607382         144.0      99.110728                1.452920
# 37        7.439929         112.0     111.598937                1.003594
# 38        8.737906         114.0     131.068588                0.869774
# 39       11.975867         205.0     179.637998                1.141184
# ------------------------------------------------------------------------------------------------
# Held-out biological-unit aggregate counts: Owls
# ------------------------------------------------------------------------------------------------
#                Nest  Observed  Directing baseline only  Linear Poisson AIM  \
# 0        AutavauxTV      31.0                38.163043           38.699689
# 1            Bochet      56.0                24.440994           29.134454
# 2           ChEsard      42.0                41.821510           58.211341
# 3       Champmartin       7.0                31.196739           39.166522
# 4          Chevroux      17.0                 6.961353            8.735776
# 5   CorcellesFavres      22.0                10.179842            8.606019
# 6          Etrabloz      32.0                30.163043           33.533795
# 7             Forel       0.0                 4.093168            3.713674
# 8            Franex      25.0                33.185255           39.686263
# 9              GDLV      12.0                11.108696           14.315191
# 10       Gletterens       6.0                 9.697826           11.478857
# 11          Henniez      23.0                 4.297826            5.991825
# 12            Jeuss      11.0                 9.033816            8.978945
# 13      LesPlanches      13.0                14.890528           23.528810
# 14           Lucens      74.0                23.676522           34.388563
# 15            Lully      18.0                18.820972           19.698697
# 16          Marnand       9.0                28.837429           27.719600
# 17           Montet      87.0                56.163043           63.317173
# 18           Murist      58.0                36.345756           56.827005
# 19           Oleyes      61.0                99.663043           90.710090
# 20          Payerne      42.0                31.966403           36.001129
# 21           Rueyes      20.0                19.526854           18.531436
# 22            Seiry      57.0                30.152853           30.060811
# 23            Sevaz       1.0                 1.575099            1.212901
# 24          StAubin      12.0                26.821946           29.453477
# 25             Trey      39.0                33.033816           32.597481
# 26         Yvonnand      72.0                76.797641           72.463103
#
#     Spline Poisson AIM  Poisson Gradient Boosting  Neural AIM-DSPP
# 0            40.233687                  36.486610        36.690171
# 1            25.060892                  22.267947        26.797411
# 2            51.260778                  54.199116        51.202920
# 3            28.756223                  21.972054        36.516360
# 4             9.653892                   6.295239         7.932598
# 5             9.323319                   9.849593         8.772217
# 6            36.146321                  34.796529        31.191449
# 7             3.260215                   2.376518         3.651488
# 8            41.396143                  42.548815        37.790915
# 9            15.063429                  18.616987        13.791465
# 10           11.260269                  12.486342         9.931401
# 11            7.121042                   7.421836         5.888623
# 12           10.392401                  13.876848         8.292603
# 13           20.796442                  26.863039        22.501069
# 14           35.895762                  49.644996        31.646605
# 15           19.580198                  26.336000        18.643988
# 16           27.618594                  29.562480        26.265587
# 17           60.362753                  53.777164        57.388440
# 18           61.676964                  70.994115        52.169868
# 19           94.276560                 110.003964        82.893588
# 20           37.078520                  33.413394        34.148639
# 21           18.671222                  24.034999        18.449755
# 22           24.909406                  25.329477        28.313923
# 23            4.011190                   1.091618         1.198164
# 24           30.422031                  27.155964        27.780429
# 25           34.533261                  27.614111        31.833218
# 26           65.855295                  64.001351        67.890551
# ------------------------------------------------------------------------------------------------
# Cluster-bootstrap uncertainty: Owls
# ------------------------------------------------------------------------------------------------
#                         Model           Metric  BootstrapMean     CI2.5  \
# 0     Directing baseline only              NLL       5.540825  4.638044
# 1     Directing baseline only  PoissonDeviance       8.271532  6.561792
# 2     Directing baseline only             RMSE       7.252236  6.133169
# 3     Directing baseline only              MAE       5.830539  4.952402
# 4          Linear Poisson AIM              NLL       4.886885  4.216427
# 5          Linear Poisson AIM  PoissonDeviance       6.963652  5.641577
# 6          Linear Poisson AIM             RMSE       6.555460  5.670034
# 7          Linear Poisson AIM              MAE       5.293566  4.580739
# 8          Spline Poisson AIM              NLL       4.778726  4.101234
# 9          Spline Poisson AIM  PoissonDeviance       6.747335  5.405948
# 10         Spline Poisson AIM             RMSE       6.449141  5.488661
# 11         Spline Poisson AIM              MAE       5.127466  4.410822
# 12  Poisson Gradient Boosting              NLL       5.170927  4.251239
# 13  Poisson Gradient Boosting  PoissonDeviance       7.531737  5.863210
# 14  Poisson Gradient Boosting             RMSE       6.853150  5.819744
# 15  Poisson Gradient Boosting              MAE       5.229471  4.448357
# 16            Neural AIM-DSPP              NLL       4.949286  4.282371
# 17            Neural AIM-DSPP  PoissonDeviance       7.088455  5.745922
# 18            Neural AIM-DSPP             RMSE       6.596645  5.666207
# 19            Neural AIM-DSPP              MAE       5.236484  4.518467
#
#        CI97.5
# 0    6.582473
# 1   10.209691
# 2    8.360110
# 3    6.771296
# 4    5.653287
# 5    8.403258
# 6    7.426805
# 7    5.928066
# 8    5.596485
# 9    8.346593
# 10   7.441269
# 11   5.881066
# 12   6.312206
# 13   9.867730
# 14   7.872757
# 15   6.008937
# 16   5.816279
# 17   8.615896
# 18   7.584423
# 19   5.955254
# ------------------------------------------------------------------------------------------------
# Paired cluster-bootstrap NLL differences versus Neural AIM-DSPP: Owls
# ------------------------------------------------------------------------------------------------
#                    Benchmark                  Comparison  MeanDifference  \
# 0    Directing baseline only  Benchmark NLL - Neural NLL        0.591539
# 1         Linear Poisson AIM  Benchmark NLL - Neural NLL       -0.062401
# 2         Spline Poisson AIM  Benchmark NLL - Neural NLL       -0.170560
# 3  Poisson Gradient Boosting  Benchmark NLL - Neural NLL        0.221641
#
#       CI2.5    CI97.5  BootstrapFractionNeuralBetter
# 0  0.139692  1.109244                       0.992000
# 1 -0.186761  0.053642                       0.158667
# 2 -0.425816  0.092626                       0.101333
# 3 -0.359140  0.828455                       0.756000
# ------------------------------------------------------------------------------------------------
# Neural AIM-DSPP permutation importance: epilepsy
# ------------------------------------------------------------------------------------------------
#      Feature   BaseNLL  MeanDeltaNLL  MedianDeltaNLL     CI2.5    CI97.5
# 0        age  2.838061      0.210023        0.195056  0.084497  0.367506
# 1     period  2.838061      0.026426        0.027294 -0.050539  0.104174
# 2  progabide  2.838061     -0.014141       -0.016046 -0.039069  0.012075
# 3   log_base  2.838061     -0.124188       -0.128805 -0.183662 -0.049733
# ------------------------------------------------------------------------------------------------
# Neural AIM-DSPP permutation importance: owls
# ------------------------------------------------------------------------------------------------
#        Feature   BaseNLL  MeanDeltaNLL  MedianDeltaNLL     CI2.5    CI97.5
# 0     deprived  4.951759      0.524972        0.533289  0.340326  0.723541
# 1  ArrivalTime  4.951759      0.319824        0.325721 -0.022485  0.633111
# 2    log_brood  4.951759      0.015720        0.016405 -0.038369  0.067418
# 3  male_parent  4.951759      0.000000        0.000000  0.000000  0.000000
# ------------------------------------------------------------------------------------------------
# Cross-dataset empirical performance synthesis
# ------------------------------------------------------------------------------------------------
#     Dataset                      Model       NLL  PoissonDeviance      RMSE  \
# 0  Epilepsy    Directing baseline only  2.723519         2.390240  4.386889
# 1  Epilepsy            Neural AIM-DSPP  2.838061         2.619324  4.787875
# 2  Epilepsy         Linear Poisson AIM  2.898309         2.739820  4.967169
# 3  Epilepsy         Spline Poisson AIM  3.029002         3.001206  4.483267
# 4  Epilepsy  Poisson Gradient Boosting  3.754153         4.451509  5.196815
# 5      Owls         Spline Poisson AIM  4.779443         6.748608  6.471534
# 6      Owls         Linear Poisson AIM  4.890566         6.970854  6.572898
# 7      Owls            Neural AIM-DSPP  4.951759         7.093238  6.614594
# 8      Owls  Poisson Gradient Boosting  5.166418         7.522557  6.876539
# 9      Owls    Directing baseline only  5.537747         8.265214  7.271628
#
#         MAE    PIT_KS         PIT_p  NLLImprovementOverBaselinePct
# 0  3.052083  0.295089  3.364704e-04                       0.000000
# 1  3.222433  0.323475  5.700575e-05                      -4.205666
# 2  3.341517  0.293318  3.736876e-04                      -6.417797
# 3  3.551511  0.354244  6.795061e-06                     -11.216484
# 4  3.727736  0.239571  6.570952e-03                     -37.842014
# 5  5.133484  0.343026  4.124171e-13                      13.693353
# 6  5.298310  0.333308  2.189966e-12                      11.686707
# 7  5.242477  0.332273  2.608281e-12                      10.581706
# 8  5.229103  0.315453  4.100155e-11                       6.705408
# 9  5.830120  0.320222  1.907561e-11                       0.000000
# ------------------------------------------------------------------------------------------------
# Post-fit geometric normalization of the neural AIM representation
# ------------------------------------------------------------------------------------------------
#     Dataset  TrainMeanLogRatioCenter  GlobalScaleExpCenter  \
# 0  Epilepsy                 0.062759              1.064770
# 1      Owls                 0.015888              1.016015
#
#    CenteredMultiplierGeometricMeanOnTrain
# 0                                     1.0
# 1                                     1.0
# ================================================================================================
# REAL BIOLOGICAL DATA ANALYSIS COMPLETE
# ================================================================================================
# Output folder: /content/AIM_DSPP_RealBiology_Outputs
# ZIP archive:   /content/AIM_DSPP_RealBiology_Outputs.zip
# All substantive tables were printed inline and all figures were displayed inline.
# Please send the resulting ZIP back for the manuscript empirical-application section.
# Triggering Colab download of the ZIP ...
